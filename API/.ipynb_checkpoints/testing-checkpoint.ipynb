# %%
import numpy as np
import kpm
import wget
import os
import pickle

# %%
url = 'https://www.emilyjgriffith.com/s/'
#if(os.path.isfile('lnqs.npy')==False): wget.download(url+'lnqs.npy') # W22 q vectors
#if(os.path.isfile('lnAs.npy')==False): wget.download(url+'lnAs.npy') # W22 A vectors
#if(os.path.isfile('alldata_train.npy')==False): wget.download(url+'alldata_train.npy') # APOGEE stellar abundances
#if(os.path.isfile('allivars_train.npy')==False): wget.download(url+'allivars_train.npy') # APOGEE stellar abundance inverse variance

# %%
elements  = np.array(['Mg','O','Si','S','Ca','CN','Na','Al','K','Cr','Fe','Ni','Mn','Co','Ce'])
alldata = np.load('alldata_train.npy')
allivars = np.load('allivars_train.npy')

data = kpm.abund_data(elements, alldata, allivars)

# %%
data
# Out:
# kpm.abund_data{
#     Elements ------------ > ['Mg' 'O' 'Si' 'S' 'Ca' 'CN' 'Na' 'Al' 'K' 'Cr' 'Fe' 'Ni' 'Mn' 'Co' 'Ce']
#     Number of elements -- > 15
#     Number of stars ----- > 48659
# }

# %%
fixed = kpm.fixed_params(data, K=2)

# %%
knot_xs = np.array([[-0.8, -0.5, -0.4, -0.3, -0.2, -0.1, 0.0, 0.1, 0.2, 0.3, 0.6],
                    [-0.8, -0.5, -0.4, -0.3, -0.2, -0.1, 0.0, 0.1, 0.2, 0.3, 0.6]])

# %%
fixed.knot_xs = knot_xs

# %%
fixed
# Out:
# kpm.fixed_params{
#     K ------------------- > 2
#     Processes ----------- > ['CC' 'Ia']
#     CC element ---------- > Mg
#     Ia element ---------- > Fe
#     q_CC_Fe ------------- > 0.4
#     dq_CC_Fe_dZ --------- > 0.0
#     Number of knots ----- > 11
#     Lambda a ------------ > 1000000.0
#     Lambda c ------------ > 1000.0
#     Lambda_d ------------ > 1000.0
# }

# %%
data, fixed, fit = kpm.run_kpm(data, fixed, '/Users/emilygriffith/KProcessModel/API/test_fits', 'MW_disk', N_itters=3, overwrite=False)
# Out:
# A-step(): fixing small elements: 18 -1123.7827
# initialize_2(): [-0.8170602]
# q-step(): fixing small elements: 13 -68.01962
# A-step(): fixing bad elements: 4
# A-step(): fixing large elements: 10 865.1669
# A-step(): fixing small elements: 137 -733030.1
# initialize_2(): [-0.6425985]
# File /Users/emilygriffith/KProcessModel/API/test_fits/MW_disk_K2_qccFe0.4_dq0.0_0.out exists, but overwriting
# A-step(): fixing large elements: 3 66216.78
# A-step(): fixing small elements: 60 -977999170.0
# 9195494.0 9536966.0 5156135.0 5156135.5 4887631.5
# Aq-step(): we took a step! -5 4887631.5 4307862.5
# A-step(): fixing large elements: 1 2511.9531
# A-step(): fixing small elements: 11 -764516.9
# 4887631.5 4915605.5 4606018.5 4606018.5 4402431.5
# Aq-step(): we took a step! -5 4402431.5 485200.0
# A-step(): fixing small elements: 1 -4307.2886
# 4402431.5 4428748.5 4212483.5 4212483.5 4065873.2
# Aq-step(): we took a step! -5 4065873.2 336558.25
# File /Users/emilygriffith/KProcessModel/API/test_fits/MW_disk_K2_qccFe0.4_dq0.0_1.out exists, but overwriting
# 2642835.8 2685834.5 2550442.5 2550442.5 2485723.5
# Aq-step(): we took a step! -5 2485723.5 157112.25
# 2485723.5 2506830.8 2439163.5 2439164.0 2407098.5
# Aq-step(): we took a step! -5 2407098.5 78625.0
# 2407098.5 2427732.2 2374904.0 2374904.2 2349969.8
# Aq-step(): we took a step! -5 2349969.8 57128.75
# File /Users/emilygriffith/KProcessModel/API/test_fits/MW_disk_K2_qccFe0.4_dq0.0_2.out exists, but overwriting
# 1837912.4 1861831.6 1822238.0 1822238.1 1797709.2
# Aq-step(): we took a step! -5 1797709.2 40203.125
# 1797709.2 1816079.1 1786743.6 1786743.5 1771051.2
# Aq-step(): we took a step! -5 1771051.2 26658.0
# 1771051.2 1789156.8 1765552.9 1765553.0 1752073.1
# Aq-step(): we took a step! -5 1752073.1 18978.125

# %%
kpm.plot_qs(data, fixed, fit)

# %%
kpm.plot_As(fit)

# %%
kpm.plot_model_abundances(data, fixed, fit, noise=False)
